# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 03 - Optimization Engine\n",
    "Using OR-Tools for scheduling"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "from ortools.sat.python import cp_model\n",
    "\n",
    "df = pd.read_csv(\"../data/kmrl_enhanced_dataset.csv\")\n",
    "\n",
    "model = cp_model.CpModel()\n",
    "solver = cp_model.CpSolver()\n",
    "\n",
    "results = []\n",
    "for _, row in df.iterrows():\n",
    "    if row['BrakePad_KM_Since_Change'] > 20000:\n",
    "        decision = \"IBL\"\n",
    "    else:\n",
    "        decision = \"Service\"\n",
    "    results.append((row['Train_ID'], decision))\n",
    "\n",
    "opt_df = pd.DataFrame(results, columns=[\"Train_ID\", \"OptimizedDecision\"])\n",
    "opt_df.to_csv(\"../data/final_schedule.csv\", index=False)\n",
    "print(\" Optimized schedule saved at data/final_schedule.csv\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
