# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01 - Data Analysis\n",
    "Exploring the KMRL dataset"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "# Load dataset\n",
    "df = pd.read_csv(\"../data/kmrl_enhanced_dataset.csv\")\n",
    "print(df.head())\n",
    "\n",
    "# Summary\n",
    "print(df.info())\n",
    "\n",
    "# Distribution of Decision_Today\n",
    "df['Decision_Today'].value_counts().plot(kind='bar')\n",
    "plt.title(\"Decision Distribution\")\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
